# %% [markdown]
# <div style="float:right;padding-top:20px">
#    <img src="https://github.com/boudjelaba/Utiles/blob/main/Logo/Carnus_1.png?raw=true" style="width:60px"/>
# </div>
#
# # Exercices :
# Document à compléter et à envoyer par Mail avant le mardi 31 janvier 2023 à 09h50
#
# Effectuer un double-clic sur la cellule bleue puis remplacer "Nom" par votre nom et "Prénom" par votre prénom. Puis exécuter la cellule.

# %% [markdown]
# <div style="padding-top: 40px">
# <div class="alert alert-info" role="alert" >
#     <ul>
#         <li><b>Nom et Prénom :</b> Nom Prénom</li>
#      </ul>
# </div>
# </div>

# %% [markdown]
# ## Installation de la librairie Pandas :
#
# ![](Insta.png)
#
# ## Autres méthodes d'installation :
#
# - Vous pouvez l'installer via le Terminal :
#
# `pip install pandas`
#
# Ou
#
# `conda install pandas`

# %% [markdown]
# ---
# ## Exercice 1 :
#
# Le code suivant génère les données "x" et "y" ("y" contient plusieurs colonnes)
#
# <div style="padding-top: 10px">
#     <ul>
#         <li> <b>Enregistrer ces données dans un seul fichier csv nommé Donnees.csv. </b></li>
#         <li> <b>Ecrire un code pour lire ce fichier. </b></li>
#         <li> <b>Lire les données contenues dans ce fichier. </b></li>
#         <li> <b>Calculer la moyenne de la deuxième colonne de "y". </b></li>
#         <li> <b>Tracer la deuxième colonne de "y" en fonction de "x". </b></li>
#         <li> <b>Supprimer la 3ème colonne de "y" et enregistrer ce nouveau tableau dans un fichier csv nommé Donnees3.csv. </b></li>
#      </ul>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace(0,10,50,endpoint=True)
y = np.cumsum(np.random.randn(50,6),0)

plt.figure(figsize=(10,5))
plt.plot(x,y)
plt.legend('abcdef', ncol=2, loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ## Exercice 1 : Solution

# %% [markdown]
# <div style="padding-top: 10px">
#     <ul>
#         <li> <b>Enregistrer ces données dans un seul fichier csv nommé Donnees.csv. </b></li>
#     </ul>
# </div>

# %%
# Out:
# dimension de x est :  (50,)
# dimensions de y est :  (50, 6)

# %% [markdown]
# <div style="padding-top: 10px">
#     <ul>
#         <li> <b>Ecrire un code pour lire ce fichier. </b></li>
#      </ul>
# </div>

# %% [markdown]
# <div style="padding-top: 10px">
#     <ul>
#         <li> <b>Lire les données contenues dans ce fichier. </b></li>
# </div>

# %%
# Out:
#           x         a         b         c         d         e         f
# 0  0.000000 -2.115121 -1.377719 -0.352450  0.241014  0.417483 -0.710472
# 1  0.204082 -2.188028 -0.780561 -0.562223  1.183271  0.942779 -1.953677
# 2  0.408163 -2.742022 -1.730577 -1.935120  2.541003 -0.082456 -1.730095
# 3  0.612245 -2.403531 -1.200339 -1.945150  2.659943 -0.597274 -2.560553
# 4  0.816327 -1.516729 -0.201047 -0.774098  2.030658 -0.234130 -3.150831
# 5  1.020408 -0.370440 -2.272082  1.110045  1.625688 -1.740530 -2.662348
# 6  1.224490 -2.333867 -3.315175  1.135791  3.665119 -1.234183 -3.644281
# 7  1.428571 -3.371951 -2.994108  1.930233  2.914570 -0.923817 -3.328777

# %% [markdown]
# <div style="padding-top: 10px">
#     <ul>
#         <li> <b>Calculer la moyenne de la deuxième colonne de "y". </b></li>
#      </ul>
# </div>

# %%
# Out:
# La moyenne de la 2ème colonne de y est :  -4.955547842519169

# %% [markdown]
# <div style="padding-top: 10px">
#     <ul>
#         <li> <b>Tracer la deuxième colonne de "y" en fonction de "x". </b></li>
#      </ul>
# </div>

# %% [markdown]
# <div style="padding-top: 10px">
#     <ul>
#         <li> <b>Supprimer la 3ème colonne de "y" et enregistrer ce nouveau tableau dans un fichier csv nommé Donnees3.csv. </b></li>
#      </ul>
# </div>

# %%
# Out:
#           x         a         b         d         e         f
# 0  0.000000 -2.115121 -1.377719  0.241014  0.417483 -0.710472
# 1  0.204082 -2.188028 -0.780561  1.183271  0.942779 -1.953677
# 2  0.408163 -2.742022 -1.730577  2.541003 -0.082456 -1.730095
# 3  0.612245 -2.403531 -1.200339  2.659943 -0.597274 -2.560553
# 4  0.816327 -1.516729 -0.201047  2.030658 -0.234130 -3.150831

# %% [markdown]
# ---
# ## Exercice 2 :
#
# Soit la chaîne de caractère suivante :
# `"a'99.7;10\\r\n", "b'101;14\\r\n", "c'102;16\\r\n", "d'103;18\\r\n"`
#
# - Ecrire un code pour extraire les chiffres contenus dans cette chaîne (x1 doit contenir les valeurs 99.7, 101, 102 et 103; et x2 doit contenir les autres valeurs : 10, 14, 16 et 18
# - Enregistrer ces chiffres dans un fichier texte nommé Texte.txt
# - Lire ce fichier texte et tracer x2 en fonction de x1

# %%
# Out:
# ['99.7;10', '101;14', '102;16', '103;18']

# %% [markdown]
# ---
# ## Exercice 3 :
#
# En utilisant la librairie __Pandas__, construire le tableau suivant :
#
# |    |Nom | Spécialité | CP | Chiffre1 | Chiffre2 | Date | Adresse|
# |---:|---------:|---:|-------:|------:|----:|-----:|---:|
# |0 | Nom1 | SN | 12000 | 1.5 | 10 | 12/03/2020 09:55 | 20 Rue A, Rodez, Av 12000|
# |1 | Nom2 | IMRT | 31000 | 5.0 | 08 | 11/02/2020 11:01 | 1 Avenue B, Toulouse, Hg 31000|
# |2 | Nom3 | IMRT | 75000 | 12.0 | 15 | 10/01/2020 13:30 | 5 Place C, Paris, Pa 75001|
# |3 | Nom4 | SN | 12000 | 3.1 | 20 | 09/12/2019 17:25 | 3 Rue D, Rodez, Av 12OOO|
#
# - Afficher ce tableau

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1 Chiffre2              Date  \
# 0  Nom1         SN  12000       1.5       10  12/03/2020 09:55
# 1  Nom2       IMRT  31000       5.0       08  11/02/2020 11:01
# 2  Nom3       IMRT  75000      12.0       15  10/01/2020 13:30
# 3  Nom4         SN  12000       3.1       20  09/12/2019 17:25
#
#                              Adresse
# 0          20 Rue A, Rodez, Av 12000
# 1     1 Avenue B, Toulouse, Hg 31000
# 2  5 Place C, Paris,        Pa 75001
# 3           3 Rue D, Rodez, Av 12OOO

# %% [markdown]
# A partir de maintenant, vous allez travailler avec le fichier fourni : Fichier.csv (Voir mail ou GitHub)
#
# - Ecrire un code pour lire le fichier "Fichier.csv"
# - Ecrire un code pour extraire le jour à partir de la date et ajouter à la fin, la colonne Jour et afficher le tableau
# - Ecrire un code pour extraire le mois à partir de la date et ajouter à la fin, la colonne Mois et afficher le tableau
# - Ecrire un code pour extraire le nom de la ville à partir de l'adresse et ajouter à la fin, la colonne Ville et afficher le tableau
#
# Votre tableau doit ressembler à ça :
#
# | |Nom | Spécialité | CP | Chiffre1 | Chiffre2 | Date | Adresse | Jour | Mois| Ville |
# |---:|---------:|---:|-------:|------:|----:|-----:|---:|----:|---:| ---:|
# |0 | Nom1 | SN | 12000 | 1.5 | 10 | 12/03/2020 09:55 | 20 Rue A, Rodez, Av 12000| 12 | 03 |Rodez|
# |1 | Nom2 | IMRT | 31000 | 5.0 | 08 | 11/02/2020 11:01 | 1 Avenue B, Toulouse, Hg 31000| 11 | 02 |Toulouse|
# |2 | Nom3 | IMRT | 75000 | 12.0 | 15 | 10/01/2020 13:30 | 5 Place C, Paris, Pa 75001| 10 | 01 |Paris|
# |3 | Nom4 | SN | 12000 | 3.1 | 20 | 09/12/2019 17:25 | 3 Rue D, Rodez, Av 12OOO| 09 | 12 |Rodez|

# %% [markdown]
# - Ecrire un code pour lire le fichier "Fichier.csv"

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2              Date  \
# 0  Nom1         SN  12000       1.5        10  12/03/2020 09:55
# 1  Nom2       IMRT  31000       5.0         8  11/02/2020 11:01
# 2  Nom3       IMRT  75000      12.0        15  10/01/2020 13:30
# 3  Nom4         SN  12000       3.1        20  09/12/2019 17:25
#
#                              Adresse
# 0          20 Rue A, Rodez, Av 12000
# 1     1 Avenue B, Toulouse, Hg 31000
# 2  5 Place C, Paris,        Pa 75001
# 3           3 Rue D, Rodez, Av 12OOO

# %% [markdown]
# - Ecrire un code pour extraire le jour à partir de la date et ajouter à la fin, la colonne Jour et afficher le tableau

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2              Date  \
# 0  Nom1         SN  12000       1.5        10  12/03/2020 09:55
# 1  Nom2       IMRT  31000       5.0         8  11/02/2020 11:01
# 2  Nom3       IMRT  75000      12.0        15  10/01/2020 13:30
# 3  Nom4         SN  12000       3.1        20  09/12/2019 17:25
#
#                              Adresse Jour
# 0          20 Rue A, Rodez, Av 12000   12
# 1     1 Avenue B, Toulouse, Hg 31000   11
# 2  5 Place C, Paris,        Pa 75001   10
# 3           3 Rue D, Rodez, Av 12OOO   09

# %% [markdown]
# - Ecrire un code pour extraire le mois à partir de la date et ajouter à la fin, la colonne Mois et afficher le tableau

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2              Date  \
# 0  Nom1         SN  12000       1.5        10  12/03/2020 09:55
# 1  Nom2       IMRT  31000       5.0         8  11/02/2020 11:01
# 2  Nom3       IMRT  75000      12.0        15  10/01/2020 13:30
# 3  Nom4         SN  12000       3.1        20  09/12/2019 17:25
#
#                              Adresse Jour Mois
# 0          20 Rue A, Rodez, Av 12000   12   03
# 1     1 Avenue B, Toulouse, Hg 31000   11   02
# 2  5 Place C, Paris,        Pa 75001   10   01
# 3           3 Rue D, Rodez, Av 12OOO   09   12

# %% [markdown]
# - Ecrire un code pour extraire le nom de la ville à partir de l'adresse et ajouter à la fin, la colonne Ville et afficher le tableau

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2              Date  \
# 0  Nom1         SN  12000       1.5        10  12/03/2020 09:55
# 1  Nom2       IMRT  31000       5.0         8  11/02/2020 11:01
# 2  Nom3       IMRT  75000      12.0        15  10/01/2020 13:30
# 3  Nom4         SN  12000       3.1        20  09/12/2019 17:25
#
#                              Adresse Jour Mois      Ville
# 0          20 Rue A, Rodez, Av 12000   12   03      Rodez
# 1     1 Avenue B, Toulouse, Hg 31000   11   02   Toulouse
# 2  5 Place C, Paris,        Pa 75001   10   01      Paris
# 3           3 Rue D, Rodez, Av 12OOO   09   12      Rodez

# %% [markdown]
# - Supprimer la colonne Jour
# - Changer le format de la date (Voir ReadMe.md)
# - Ecrire un code pour extraire les heures à partir de la date et ajouter à la fin, la colonne Heure et afficher le tableau
# - Ecrire un code pour extraire les minutes à partir de la date et ajouter à la fin, la colonne Minute et afficher le tableau
#
# Votre tableau doit ressembler à ça :
#
# | |Nom | Spécialité | CP | Chiffre1 | Chiffre2 | Date | Adresse| Mois| Ville |Heure|Minute|
# |---:|---------:|---:|-------:|------:|----:|-----:|---:|----:|---:| ---:|---:|
# |0 | Nom1 | SN | 12000 | 1.5 | 10 | 2020-12-03 09:55:00 | 20 Rue A, Rodez, Av 12000| 03 |Rodez|09|55|
# |1 | Nom2 | IMRT | 31000 | 5.0 | 08 | 2020-11-02 11:01:00 | 1 Avenue B, Toulouse, Hg 31000| 02 |Toulouse|11|01|
# |2 | Nom3 | IMRT | 75000 | 12.0 | 15 | 2020-10-01 13:30:00 | 5 Place C, Paris, Pa 75001| 01 |Paris|13|30|
# |3 | Nom4 | SN | 12000 | 3.1 | 20 | 2019-09-12 17:25:00 | 3 Rue D, Rodez, Av 12OOO| 12 |Rodez|17|25|

# %% [markdown]
# - Supprimer la colonne Jour

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2              Date  \
# 0  Nom1         SN  12000       1.5        10  12/03/2020 09:55
# 1  Nom2       IMRT  31000       5.0         8  11/02/2020 11:01
# 2  Nom3       IMRT  75000      12.0        15  10/01/2020 13:30
# 3  Nom4         SN  12000       3.1        20  09/12/2019 17:25
#
#                              Adresse Mois      Ville
# 0          20 Rue A, Rodez, Av 12000   03      Rodez
# 1     1 Avenue B, Toulouse, Hg 31000   02   Toulouse
# 2  5 Place C, Paris,        Pa 75001   01      Paris
# 3           3 Rue D, Rodez, Av 12OOO   12      Rodez

# %% [markdown]
# - Changer le format de la date (Voir ReadMe.md)

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2                Date  \
# 0  Nom1         SN  12000       1.5        10 2020-12-03 09:55:00
# 1  Nom2       IMRT  31000       5.0         8 2020-11-02 11:01:00
# 2  Nom3       IMRT  75000      12.0        15 2020-10-01 13:30:00
# 3  Nom4         SN  12000       3.1        20 2019-09-12 17:25:00
#
#                              Adresse Mois      Ville
# 0          20 Rue A, Rodez, Av 12000   03      Rodez
# 1     1 Avenue B, Toulouse, Hg 31000   02   Toulouse
# 2  5 Place C, Paris,        Pa 75001   01      Paris
# 3           3 Rue D, Rodez, Av 12OOO   12      Rodez

# %% [markdown]
# - Ecrire un code pour extraire les heures à partir de la date et ajouter à la fin, la colonne Heure et afficher le tableau

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2                Date  \
# 0  Nom1         SN  12000       1.5        10 2020-12-03 09:55:00
# 1  Nom2       IMRT  31000       5.0         8 2020-11-02 11:01:00
# 2  Nom3       IMRT  75000      12.0        15 2020-10-01 13:30:00
# 3  Nom4         SN  12000       3.1        20 2019-09-12 17:25:00
#
#                              Adresse Mois      Ville  Heure
# 0          20 Rue A, Rodez, Av 12000   03      Rodez      9
# 1     1 Avenue B, Toulouse, Hg 31000   02   Toulouse     11
# 2  5 Place C, Paris,        Pa 75001   01      Paris     13
# 3           3 Rue D, Rodez, Av 12OOO   12      Rodez     17

# %% [markdown]
# - Ecrire un code pour extraire les minutes à partir de la date et ajouter à la fin, la colonne Minute et afficher le tableau

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2                Date  \
# 0  Nom1         SN  12000       1.5        10 2020-12-03 09:55:00
# 1  Nom2       IMRT  31000       5.0         8 2020-11-02 11:01:00
# 2  Nom3       IMRT  75000      12.0        15 2020-10-01 13:30:00
# 3  Nom4         SN  12000       3.1        20 2019-09-12 17:25:00
#
#                              Adresse Mois      Ville  Heure  Minute
# 0          20 Rue A, Rodez, Av 12000   03      Rodez      9      55
# 1     1 Avenue B, Toulouse, Hg 31000   02   Toulouse     11       1
# 2  5 Place C, Paris,        Pa 75001   01      Paris     13      30
# 3           3 Rue D, Rodez, Av 12OOO   12      Rodez     17      25

# %% [markdown]
# En utilisant l'instruction `type`, on remarque que la colonne "Mois" est de type string. De même pour la colonne "Chiffre2".
#
# ```python
# print(type(NomDeVotreTableau['Mois'][0]))
# ```
#
# `<class 'str'>`
#
# - Ecrire un code pour mettre au format *integer* la colonne "Mois" et vérifier vos résultats
# - Ecrire un code pour mettre au bon format *integer* la colonne "Chiffre2" et vérifier vos résultats
#
# | |Nom | Spécialité | CP | Chiffre1 | Chiffre2 | Date | Adresse| Mois| Ville |Heure|Minute|
# |---:|---------:|---:|-------:|------:|----:|-----:|---:|----:|---:| ---:|---:|
# |0 | Nom1 | SN | 12000 | 1.5 | 10 | 2020-12-03 09:55:00 | 20 Rue A, Rodez, Av 12000| 3 |Rodez|09|55|
# |1 | Nom2 | IMRT | 31000 | 5.0 | 8 | 2020-11-02 11:01:00 | 1 Avenue B, Toulouse, Hg 31000| 2 |Toulouse|11|01|
# |2 | Nom3 | IMRT | 75000 | 12.0 | 15 | 2020-10-01 13:30:00 | 5 Place C, Paris, Pa 75001| 1 |Paris|13|30|
# |3 | Nom4 | SN | 12000 | 3.1 | 20 | 2019-09-12 17:25:00 | 3 Rue D, Rodez, Av 12OOO| 12 |Rodez|17|25|

# %% [markdown]
# - Ecrire un code pour mettre au format *integer* la colonne "Mois" et vérifier vos résultats

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2                Date  \
# 0  Nom1         SN  12000       1.5        10 2020-12-03 09:55:00
# 1  Nom2       IMRT  31000       5.0         8 2020-11-02 11:01:00
# 2  Nom3       IMRT  75000      12.0        15 2020-10-01 13:30:00
# 3  Nom4         SN  12000       3.1        20 2019-09-12 17:25:00
#
#                              Adresse Mois      Ville  Heure  Minute
# 0          20 Rue A, Rodez, Av 12000   03      Rodez      9      55
# 1     1 Avenue B, Toulouse, Hg 31000   02   Toulouse     11       1
# 2  5 Place C, Paris,        Pa 75001   01      Paris     13      30
# 3           3 Rue D, Rodez, Av 12OOO   12      Rodez     17      25

# %%
# Out:
# <class 'str'>

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2                Date  \
# 0  Nom1         SN  12000       1.5        10 2020-12-03 09:55:00
# 1  Nom2       IMRT  31000       5.0         8 2020-11-02 11:01:00
# 2  Nom3       IMRT  75000      12.0        15 2020-10-01 13:30:00
# 3  Nom4         SN  12000       3.1        20 2019-09-12 17:25:00
#
#                              Adresse  Mois      Ville  Heure  Minute
# 0          20 Rue A, Rodez, Av 12000     3      Rodez      9      55
# 1     1 Avenue B, Toulouse, Hg 31000     2   Toulouse     11       1
# 2  5 Place C, Paris,        Pa 75001     1      Paris     13      30
# 3           3 Rue D, Rodez, Av 12OOO    12      Rodez     17      25

# %%
# Out:
# <class 'numpy.int32'>

# %% [markdown]
# - Ecrire un code pour mettre au bon format *integer* la colonne "Chiffre2" et vérifier vos résultats

# %%
# Out:
# <class 'int'>

# %% [markdown]
# __Remarque :__
# Le logiciel nous informe que la colonne "Chiffre2" est de `<class 'int'>` qui n'a rien avoir avec les entiers.    Si la colonne "Chiffre2" ne contient que des entiers, le logiciel doit afficher `<class 'numpy.int64'>` ou `<class 'numpy.int32'>` (voir les résultats de la conversion de la colonne "Mois")

# %%
# Out:
# <class 'int'>
# <class 'numpy.float64'>

# %%
# Cette étape n'est pas demandée dans l'énoncé
"""
On crée une copie des données pour ne pas modifier df car on a besoin
de df pour les questions suivantes
"""
# On commence par convertir la colonne "Chiffre2" en chaîne de caractères
dfz = df.copy()
dfz['Chiffre2'] = df['Chiffre2'].map({10:'10', '08':'08', 15:'15', 20:'20'})
dfz.head()
# Out:
#     Nom Spécialité     CP  Chiffre1 Chiffre2                Date  \
# 0  Nom1         SN  12000       1.5       10 2020-12-03 09:55:00
# 1  Nom2       IMRT  31000       5.0       08 2020-11-02 11:01:00
# 2  Nom3       IMRT  75000      12.0       15 2020-10-01 13:30:00
# 3  Nom4         SN  12000       3.1       20 2019-09-12 17:25:00
#
#                              Adresse  Mois      Ville  Heure  Minute
# 0          20 Rue A, Rodez, Av 12000     3      Rodez      9      55
# 1     1 Avenue B, Toulouse, Hg 31000     2   Toulouse     11       1
# 2  5 Place C, Paris,        Pa 75001     1      Paris     13      30
# 3           3 Rue D, Rodez, Av 12OOO    12      Rodez     17      25

# %%
# Out:
# <class 'str'>

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2                Date  \
# 0  Nom1         SN  12000       1.5        10 2020-12-03 09:55:00
# 1  Nom2       IMRT  31000       5.0         8 2020-11-02 11:01:00
# 2  Nom3       IMRT  75000      12.0        15 2020-10-01 13:30:00
# 3  Nom4         SN  12000       3.1        20 2019-09-12 17:25:00
#
#                              Adresse  Mois      Ville  Heure  Minute
# 0          20 Rue A, Rodez, Av 12000     3      Rodez      9      55
# 1     1 Avenue B, Toulouse, Hg 31000     2   Toulouse     11       1
# 2  5 Place C, Paris,        Pa 75001     1      Paris     13      30
# 3           3 Rue D, Rodez, Av 12OOO    12      Rodez     17      25

# %%
# Out:
# <class 'numpy.int64'>

# %% [markdown]
# - Ajouter une colonne pour calculer la moyenne entre le "Chiffre1" et le "Chiffre2"
# - Enregistrer votre fichier dans un fichier csv nommé FichierResultat.csv

# %%
# Out:
#     Nom Spécialité     CP  Chiffre1  Chiffre2                Date  \
# 0  Nom1         SN  12000       1.5        10 2020-12-03 09:55:00
# 1  Nom2       IMRT  31000       5.0         8 2020-11-02 11:01:00
# 2  Nom3       IMRT  75000      12.0        15 2020-10-01 13:30:00
# 3  Nom4         SN  12000       3.1        20 2019-09-12 17:25:00
#
#                              Adresse  Mois      Ville  Heure  Minute  Moyenne
# 0          20 Rue A, Rodez, Av 12000     3      Rodez      9      55     5.75
# 1     1 Avenue B, Toulouse, Hg 31000     2   Toulouse     11       1     6.50
# 2  5 Place C, Paris,        Pa 75001     1      Paris     13      30    13.50
# 3           3 Rue D, Rodez, Av 12OOO    12      Rodez     17      25    11.55
